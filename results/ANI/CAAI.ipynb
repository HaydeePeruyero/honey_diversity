# %% [markdown]
# # cAAI

# %%
import pandas as pd

ruta_archivo_caai = "/home/haydeeperuyero/FastANI/miel_ani_aai_caai/anvio_coreAAI.csv"
# Lread file to a Dataframe
df = pd.read_csv(ruta_archivo_caai)

# %%
df
# Out:
#                         genome1                           genome2  \
# 0            A_23_Scapto_001_v2                 A_42_Melli_004_v2
# 1            A_23_Scapto_001_v2                A_51_Scapto_004_v2
# 2            A_23_Scapto_001_v2                A_89_Scapto_001_v2
# 3            A_23_Scapto_001_v2                A_89_Scapto_002_v2
# 4            A_23_Scapto_001_v2                A_90_Scapto_012_v2
# ..                          ...                               ...
# 625                 N_barcode04        Nicoliella_lavandulae_Es01
# 626                 N_barcode04  Nicoliella_spurrieriana_SGEP1_A5
# 627                 N_barcode20        Nicoliella_lavandulae_Es01
# 628                 N_barcode20  Nicoliella_spurrieriana_SGEP1_A5
# 629  Nicoliella_lavandulae_Es01  Nicoliella_spurrieriana_SGEP1_A5
#
#      coreAA_identity_pct  compared_positions
# 0                99.6754               38505
# 1                85.1054               38336
# ...

# %%
pd.unique(df[['genome1']].values.ravel())
pd.unique(df[['genome1']].values.ravel())
# Out:
# array(['A_23_Scapto_001_v2', 'A_42_Melli_004_v2', 'A_51_Scapto_004_v2',
#        'A_89_Scapto_001_v2', 'A_89_Scapto_002_v2', 'A_90_Scapto_012_v2',
#        'A_92_Scapto_002_v2', 'A_92_Scapto_009_v2',
#        'A_apinorum_strainFhon13', 'A_jinshanensis_brasiliensis',
#        'A_jinshanensis_strainHSLZ75', 'A_jinshanensis_subsaerogenes',
#        'A_kunkeei_DSM12361', 'A_micheneri_strainHlig3',
#        'A_micheneri_strainNBRC113063', 'A_ozensis_DSM23829',
#        'A_quenuiae_strainHV6', 'A_timberlakei_strainHV12',
#        'F_florum_DSM22689', 'F_fructivorans_strainDSM20203',
#        'F_lindneri_strainDSM20690', 'F_sanfranciscensis_DSM20451',
#        'L_Lactobacillus_spSy1', 'L_senioris_DSM24302',
#        'N_22_Melli_029_v2', 'N_40_Melli_029_v2', 'N_41_Melli_001_v2',
#        'N_45_Melli_016_v2', 'N_45_Melli_020_v2', 'N_46_Melli_022_v2',
#        'N_47_Melli_001_v2', 'N_barcode03', 'N_barcode04', 'N_barcode20',
#        'Nicoliella_lavandulae_Es01'], dtype=object)

# %%
rename_dict1 = {
    'N_40_Melli_029_v2':'40_Melli.029', 
    'N_45_Melli_016_v2':'45_Melli.016', 
    'N_46_Melli_022_v2':'46_Melli.022',
    'L_Lactobacillus_spSy1':'Lactobacillus sp. Sy-1',
    'Nicoliella_lavandulae_Es01': 'N. lavandulae Es01',
    'N_22_Melli_029_v2':'22_Melli.029',
    'N_barcode03':'40_Melli_barcode03', 
    'N_45_Melli_020_v2':'45_Melli.020',
    'N_47_Melli_001_v2':'47_Melli.001',
    'N_barcode04':'39_Melli_barcode04',
    'N_41_Melli_001_v2':'41_Melli.001',
    'N_barcode20':'90_Scapto_barcode20',
    'A_jinshanensis_brasiliensis':'A. jinshanensis brasiliensis',
    'A_jinshanensis_strainHSLZ75':'A. jinshanensis strain HSLZ-75',
    'A_jinshanensis_subsaerogenes':'A. jinshanensis subsp. aerogenes',
    'A_51_Scapto_004_v2':'51_Scapto.004',
    'A_89_Scapto_002_v2':'89_Scapto.002',
    'A_90_Scapto_012_v2':'90_Scapto.012',
    'A_92_Scapto_009_v2':'92_Scapto.009',
    'A_42_Melli_004_v2':'42_Melli.004',
    'A_23_Scapto_001_v2':'23_Scapto.001', 
    'A_89_Scapto_001_v2':'89_Scapto.001',
    'A_92_Scapto_002_v2':'92_Scapto.002',
    'A_kunkeei_DSM12361':'A. kunkeei DSM-12361'
}
rename_dict2 = {
    'N_40_Melli_029_v2':'40_Melli.029', 
    'N_45_Melli_016_v2':'45_Melli.016', 
    'N_46_Melli_022_v2':'46_Melli.022',
    'L_Lactobacillus_spSy1':'Lactobacillus sp. Sy-1',
    'Nicoliella_spurrieriana_SGEP1_A5': 'N. spurrieriana SGEP1_A5', 
    'Nicoliella_lavandulae_Es01': 'N. lavandulae Es01',
    'N_22_Melli_029_v2':'22_Melli.029',
    'N_barcode03':'40_Melli_barcode03', 
    'N_45_Melli_020_v2':'45_Melli.020',
    'N_47_Melli_001_v2':'47_Melli.001',
    'N_barcode04':'39_Melli_barcode04',
    'N_41_Melli_001_v2':'41_Melli.001',
    'N_barcode20':'90_Scapto_barcode20',
    'A_jinshanensis_brasiliensis':'A. jinshanensis brasiliensis',
    'A_jinshanensis_strainHSLZ75':'A. jinshanensis strain HSLZ-75',
    'A_jinshanensis_subsaerogenes':'A. jinshanensis subsp. aerogenes',
    'A_51_Scapto_004_v2':'51_Scapto.004',
    'A_89_Scapto_002_v2':'89_Scapto.002',
    'A_90_Scapto_012_v2':'90_Scapto.012',
    'A_92_Scapto_009_v2':'92_Scapto.009',
    'A_42_Melli_004_v2':'42_Melli.004',
    'A_89_Scapto_001_v2':'89_Scapto.001',
    'A_92_Scapto_002_v2':'92_Scapto.002',
    'A_kunkeei_DSM12361':'A. kunkeei DSM-12361'
}

# %%
validos1 = set(rename_dict1.keys())   # llaves del diccionario
validos2 = set(rename_dict2.keys())   # llaves del diccionario

df_filtrado = df[
    df["genome1"].isin(validos1) & df["genome2"].isin(validos2)
]
df_filtrado
# Out:
#                         genome1                           genome2  \
# 0            A_23_Scapto_001_v2                 A_42_Melli_004_v2
# 1            A_23_Scapto_001_v2                A_51_Scapto_004_v2
# 2            A_23_Scapto_001_v2                A_89_Scapto_001_v2
# 3            A_23_Scapto_001_v2                A_89_Scapto_002_v2
# 4            A_23_Scapto_001_v2                A_90_Scapto_012_v2
# ..                          ...                               ...
# 625                 N_barcode04        Nicoliella_lavandulae_Es01
# 626                 N_barcode04  Nicoliella_spurrieriana_SGEP1_A5
# 627                 N_barcode20        Nicoliella_lavandulae_Es01
# 628                 N_barcode20  Nicoliella_spurrieriana_SGEP1_A5
# 629  Nicoliella_lavandulae_Es01  Nicoliella_spurrieriana_SGEP1_A5
#
#      coreAA_identity_pct  compared_positions
# 0                99.6754               38505
# 1                85.1054               38336
# ...

# %%
df_filtrado[["genome1"]] = df_filtrado[["genome1"]].replace(rename_dict1)
df_filtrado[["genome2"]] = df_filtrado[["genome2"]].replace(rename_dict2)
df_filtrado
# Out:
# /tmp/ipykernel_2014279/2857413136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado[["genome1"]] = df_filtrado[["genome1"]].replace(rename_dict1)
# /tmp/ipykernel_2014279/2857413136.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado[["genome2"]] = df_filtrado[["genome2"]].replace(rename_dict2)
#                  genome1                   genome2  coreAA_identity_pct  \
# 0          23_Scapto.001              42_Melli.004              99.6754
# ...

# %%
import numpy as np

# IDs únicos
ids_unicos = pd.unique(df_filtrado[['genome1', 'genome2']].values.ravel())

# Mejor inicializar con NaN en vez de 0
matriz_caai = pd.DataFrame(np.nan, index=ids_unicos, columns=ids_unicos)

# Llenar matriz simétrica
for _, row in df_filtrado.iterrows():
    g1 = row['genome1']
    g2 = row['genome2']
    val = row['coreAA_identity_pct']
    
    matriz_caai.at[g1, g2] = val
    matriz_caai.at[g2, g1] = val  # <- esto faltaba

# Opcional: poner 100 en la diagonal
np.fill_diagonal(matriz_caai.values, 100.0)

# %%
# Show the matrix
matriz_caai
# Out:
#                                   23_Scapto.001  42_Melli.004  51_Scapto.004  \
# 23_Scapto.001                          100.0000       99.6754        85.1054
# 42_Melli.004                            99.6754      100.0000        85.1189
# 51_Scapto.004                           85.1054       85.1189       100.0000
# 89_Scapto.001                           99.8884       99.6857        85.0879
# 89_Scapto.002                           85.1080       85.1163        99.9766
# 90_Scapto.012                           85.1028       85.1163        99.9792
# 92_Scapto.002                           99.8599       99.7247        85.0976
# 92_Scapto.009                           85.0990       85.1073        99.9661
# A. jinshanensis brasiliensis            69.8087       69.8092        69.9705
# A. jinshanensis strain HSLZ-75          69.1000       69.0553        69.3134
# A. jinshanensis subsp. aerogenes        69.0842       69.0396        69.2977
# ...

# %%
matriz_caai.index
# Out:
# Index(['23_Scapto.001', '42_Melli.004', '51_Scapto.004', '89_Scapto.001',
#        '89_Scapto.002', '90_Scapto.012', '92_Scapto.002', '92_Scapto.009',
#        'A. jinshanensis brasiliensis', 'A. jinshanensis strain HSLZ-75',
#        'A. jinshanensis subsp. aerogenes', 'A. kunkeei DSM-12361',
#        'Lactobacillus sp. Sy-1', '22_Melli.029', '40_Melli.029',
#        '41_Melli.001', '45_Melli.016', '45_Melli.020', '46_Melli.022',
#        '47_Melli.001', '40_Melli_barcode03', '39_Melli_barcode04',
#        '90_Scapto_barcode20', 'N. lavandulae Es01',
#        'N. spurrieriana SGEP1_A5'],
#       dtype='object')

# %%
orden = ['40_Melli.029', '45_Melli.016', '46_Melli.022', 
         'Lactobacillus sp. Sy-1',
         'N. spurrieriana SGEP1_A5', 'N. lavandulae Es01',
         '22_Melli.029','40_Melli_barcode03', '45_Melli.020','47_Melli.001','39_Melli_barcode04','41_Melli.001','90_Scapto_barcode20',
         'A. jinshanensis brasiliensis',
         'A. jinshanensis strain HSLZ-75',
         'A. jinshanensis subsp. aerogenes', 
         '51_Scapto.004','89_Scapto.002','90_Scapto.012','92_Scapto.009',
         '42_Melli.004','23_Scapto.001', '89_Scapto.001','92_Scapto.002',
         'A. kunkeei DSM-12361']
          
matriz_caai = matriz_caai.reindex(index=orden, columns=orden)

# %%
# Save the matrix to a cvs
matriz_caai.to_csv('matriz_caai.csv', index=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

annot = matriz_caai.round(2).astype(str)
annot[matriz_caai == 0] = ""

# Figure size
plt.figure(figsize=(20, 16))

# Heatmap with seaborn
ax=sns.heatmap(matriz_caai, annot=annot, fmt="", cmap="viridis", cbar=True, annot_kws={"size": 11})

# Titles and legends
plt.title("", fontsize=16)
plt.xlabel("", fontsize=18)
plt.ylabel("", fontsize=18)

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

cbar = ax.collections[0].colorbar
cbar.ax.tick_params(labelsize=16)
# Show the heatmap
plt.tight_layout()
# save into a svg
plt.savefig("heatmap_caai.svg", format="svg")
plt.show()

# %%
# Define groups
groups = {
    "Clade_1": [0, 1,2],
    "Clade_2-barcode20": [6,7,8,9,10,11],
    "Clade_2+barcode20": [6,7,8,9,10,11,12],
    "Clade_3": [16,17,18,19],
    "Clade_4": [20,21,22,23],
    "Nicoliela+Sp1":[3,4,5],
    "Nicoliela":[4,5],
    "Acetilactobacillus":[13,14,15]
}

# %%
import numpy as np
import pandas as pd
from itertools import combinations
# Compute mean, std and var
results_within = {}
for group_name, indices in groups.items():
    submatrix = matriz_caai.iloc[indices, indices]
    results_within[group_name] = {
        "mean": submatrix.values.mean(),
        "std_dev": submatrix.values.std(),
        "var": submatrix.values.var()
    }

# Compute the mean, std and var between groups
results_between = {}
for (group_name_1, indices_1), (group_name_2, indices_2) in combinations(groups.items(), 2):
    submatrix = matriz_caai.iloc[indices_1, indices_2]
    key = f"{group_name_1} vs {group_name_2}"
    results_between[key] = {
        "mean": submatrix.values.mean(),
        "std_dev": submatrix.values.std(),
        "var": submatrix.values.var()
    }

# MShow the results
print("The mean, std and var in groups:")
print(pd.DataFrame(results_within).T)

print("\nThe mean, std and var between groupss:")
print(pd.DataFrame(results_between).T)
# Out:
# The mean, std and var in groups:
#                          mean   std_dev        var
# Clade_1             99.898733  0.108691   0.011814
# Clade_2-barcode20   99.938178  0.032556   0.001060
# Clade_2+barcode20   98.686714  2.200637   4.842802
# Clade_3             99.980463  0.013103   0.000172
# Clade_4             99.834475  0.121394   0.014737
# Nicoliela+Sp1       93.054200  4.987286  24.873019
# Nicoliela           94.272700  5.727300  32.801965
# Acetilactobacillus  95.998556  4.462184  19.911084
#
# The mean, std and var between groupss:
#                                               mean   std_dev        var
# Clade_1 vs Clade_2-barcode20             76.398078  0.015699   0.000246
# Clade_1 vs Clade_2+barcode20             76.341195  0.140148   0.019642
# Clade_1 vs Clade_3                       70.695158  0.026046   0.000678
# Clade_1 vs Clade_4                       71.077183  0.021395   0.000458
# Clade_1 vs Nicoliela+Sp1                 76.237922  0.166837   0.027835
# ...

# %%
import sys
print(sys.version)
# Out:
# 3.9.19 (main, May  6 2024, 19:43:03)
# [GCC 11.2.0]

# %%
import seaborn
print(seaborn.__version__)
# Out:
# 0.13.2

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.9.0
